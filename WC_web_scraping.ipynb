# %%
import pandas as pd

# %%
WC_overview = pd.read_html('https://fbref.com/en/comps/1/World-Cup-Stats')
table = WC_overview[8]
table

#reading in the chosen table from the website
# Out:
#      Rk              Squad   MP    W    D    L    GF    GA   GD   Pts    xG  \
# 0     1       ar Argentina  7.0  4.0  2.0  1.0  15.0   8.0  7.0  14.0  15.1
# 1   NaN                NaN  NaN  NaN  NaN  NaN   NaN   NaN  NaN   NaN   NaN
# 2     2          fr France  7.0  5.0  1.0  1.0  16.0   8.0  8.0  16.0  13.8
# 3   NaN                NaN  NaN  NaN  NaN  NaN   NaN   NaN  NaN   NaN   NaN
# 4     3         hr Croatia  7.0  2.0  4.0  1.0   8.0   7.0  1.0  10.0   7.0
# 5   NaN                NaN  NaN  NaN  NaN  NaN   NaN   NaN  NaN   NaN   NaN
# 6     4         ma Morocco  7.0  3.0  2.0  2.0   6.0   5.0  1.0  11.0   6.6
# 7   NaN                NaN  NaN  NaN  NaN  NaN   NaN   NaN  NaN   NaN   NaN
# 8    QF     nl Netherlands  5.0  3.0  2.0  0.0  10.0   4.0  6.0  11.0   4.6
# 9    QF        eng England  5.0  3.0  1.0  1.0  13.0   4.0  9.0  10.0   8.6
# 10   QF          br Brazil  5.0  3.0  1.0  1.0   8.0   3.0  5.0  10.0  12.0
# ...

# %%
table = table.drop(['Notes'], axis = 1)
table = table.dropna()

#removing the unnecessary column and empty rows, 

table.to_csv('WCrankings', sep=',', index=False, encoding='utf-8')

#then writing the table to a csv file

# %%
WC_scores = pd.read_html('https://fbref.com/en/comps/1/schedule/World-Cup-Scores-and-Fixtures')
table2 = WC_scores[0]

#reading in the other chosen table 

pd.set_option('display.max_rows', 100)

#changing the notebook setting so the whole table can be viewed at once 

table2
# Out:
#                 Round   Wk  Day        Date   Time               Home   xG  \
# 0         Group stage  1.0  Sun  2022-11-20  19:00           Qatar qa  0.3
# 1         Group stage  1.0  Mon  2022-11-21  16:00        England eng  2.1
# 2         Group stage  1.0  Mon  2022-11-21  19:00         Senegal sn  0.9
# 3         Group stage  1.0  Mon  2022-11-21  22:00   United States us  0.8
# 4         Group stage  1.0  Tue  2022-11-22  13:00       Argentina ar  2.2
# 5         Group stage  1.0  Tue  2022-11-22  16:00         Denmark dk  1.4
# 6         Group stage  1.0  Tue  2022-11-22  19:00          Mexico mx  0.7
# 7         Group stage  1.0  Tue  2022-11-22  22:00          France fr  4.0
# 8         Group stage  1.0  Wed  2022-11-23  13:00         Morocco ma  0.4
# 9         Group stage  1.0  Wed  2022-11-23  16:00         Germany de  3.1
# 10        Group stage  1.0  Wed  2022-11-23  19:00           Spain es  3.5
# ...

# %%
table2 = table2.dropna(axis=0, subset=['Round'])

#removing the empty rows 

table2.to_csv('WCmatches', sep=',', index=False, encoding='utf-8')

#writing the table to a csv file
